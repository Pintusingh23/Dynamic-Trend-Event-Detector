# %%
pip install pandas numpy scikit-learn matplotlib seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

data = pd.read_json('../data/News_Category_Dataset_v3.json', lines=True)
data.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# ...

# %%
data.shape
# Out:
# (209527, 6)

# %%
data.isnull().sum()
# Out:
# link                 0
# headline             0
# category             0
# short_description    0
# authors              0
# date                 0
# dtype: int64

# %%
data['category'].value_counts()
# Out:
# category
# POLITICS          35602
# WELLNESS          17945
# ENTERTAINMENT     17362
# TRAVEL             9900
# STYLE & BEAUTY     9814
# PARENTING          8791
# HEALTHY LIVING     6694
# QUEER VOICES       6347
# FOOD & DRINK       6340
# BUSINESS           5992
# COMEDY             5400
# SPORTS             5077
# BLACK VOICES       4583
# HOME & LIVING      4320
# PARENTS            3955
# THE WORLDPOST      3664
# WEDDINGS           3653
# WOMEN              3572
# CRIME              3562
# IMPACT             3484
# DIVORCE            3426
# WORLD NEWS         3299
# MEDIA              2944
# WEIRD NEWS         2777
# GREEN              2622
# WORLDPOST          2579
# RELIGION           2577
# STYLE              2254
# SCIENCE            2206
# TECH               2104
# TASTE              2096
# MONEY              1756
# ARTS               1509
# ENVIRONMENT        1444
# FIFTY              1401
# GOOD NEWS          1398
# U.S. NEWS          1377
# ARTS & CULTURE     1339
# ...

# %%
data['date'] = pd.to_datetime(data['date'])
data.dtypes
# Out:
# link                         object
# headline                     object
# category                     object
# short_description            object
# authors                      object
# date                 datetime64[ns]
# dtype: object

# %%
data['full_text'] = data['headline'] + ' ' + data['short_description'].fillna('')
data['full_text'].head(3)
# Out:
# 0    Over 4 Million Americans Roll Up Sleeves For O...
# 1    American Airlines Flyer Charged, Banned For Li...
# 2    23 Of The Funniest Tweets About Cats And Dogs ...
# Name: full_text, dtype: object

# %%
data_sample = data.sample(n=10000, random_state=42).reset_index(drop=True)
data_sample.shape
# Out:
# (10000, 7)

# %%
#Clean function 
import re
import nltk
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-z\s]', '', text)
    words = [lemmatizer.lemmatize(w)
             for w in text.split()
             if w not in stop_words and len(w) > 2]
    return ' '.join(words)

# %%
data_sample['clean_text'] = data_sample['full_text'].apply(clean_text)
data_sample[['full_text', 'clean_text']].head(3)
# Out:
#                                            full_text  \
# 0  What If We Were All Family Generation Changers...
# 1  Firestorm At AOL Over Employee Benefit Cuts It...
# 2  Dakota Access Protesters Arrested As Deadline ...
#
#                                           clean_text
# 0  family generation changer wont create new oppo...
# 1  firestorm aol employee benefit cut glorious we...
# 2  dakota access protester arrested deadline pass...

# %%
import os
os.makedirs('../data', exist_ok=True)
data_sample.to_csv('../data/clean_data.csv', index=False)
data_sample.shape
# Out:
# (10000, 8)
